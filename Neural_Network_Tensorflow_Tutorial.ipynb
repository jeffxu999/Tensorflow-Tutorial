# %%
# Neural Network - Tensorflow Tutorial

###############################################################

import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

###############################################################

fashion_mnist = keras.datasets.fashion_mnist

(training_images,training_labels),(test_images,test_labels)=fashion_mnist.load_data()

clothe_name = ["Tshirt","Trouser","Pullover","Dress","Coat","Sandal","Shirt","Sneaker","Bag","Boot"]

scaled_training_images = training_images/255

scaled_test_images = test_images/255

###############################################################

input_layer = keras.layers.Flatten(input_shape=(28,28))

output_layer = keras.layers.Dense(10,activation=tf.nn.softmax)

hidden_layer = keras.layers.Dense(100,activation=tf.nn.relu)

shallow_neural_net = keras.Sequential([input_layer, hidden_layer, output_layer])

shallow_neural_net.compile(optimizer=tf.train.AdamOptimizer(), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

shallow_neural_net.fit(scaled_training_images, training_labels, epochs=3)

###############################################################

deep_layer_1 = keras.layers.Dense(100, activation=tf.nn.relu)
deep_layer_2 = keras.layers.Dense(100, activation=tf.nn.relu)
deep_layer_3 = keras.layers.Dense(100, activation=tf.nn.relu)
deep_layer_4 = keras.layers.Dense(100, activation=tf.nn.relu)
deep_layer_5 = keras.layers.Dense(100, activation=tf.nn.relu)

deep_neural_net = keras.Sequential([input_layer, deep_layer_1, deep_layer_2, deep_layer_3, deep_layer_4, deep_layer_5, output_layer])

deep_neural_net.compile(optimizer=tf.train.AdamOptimizer(), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

deep_neural_net.fit(scaled_training_images, training_labels, epochs=3)

###############################################################

loss, accuracy = deep_neural_net.evaluate(scaled_test_images,test_labels)

print(accuracy)

predictions = deep_neural_net.predict(scaled_test_images)

for index in range(25):
    print("Prediction : ", clothe_name[np.argmax(predictions[index])])
    print("Actual : ", clothe_name[test_labels[index]])
    plt.imshow(test_images[index])
    plt.show()
# Out:
# Epoch 1/3
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.5105 - acc: 0.8212
# Epoch 2/3
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.3864 - acc: 0.8626
# Epoch 3/3
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.3482 - acc: 0.8738
# Epoch 1/3
# 60000/60000 [==============================] - 7s 121us/step - loss: 0.5073 - acc: 0.8160
# Epoch 2/3
# 60000/60000 [==============================] - 7s 117us/step - loss: 0.3803 - acc: 0.8610
# Epoch 3/3
# 60000/60000 [==============================] - 7s 116us/step - loss: 0.3481 - acc: 0.8725
# 10000/10000 [==============================] - 1s 70us/step
# 0.8623
# Prediction :  Boot
# Actual :  Boot
# Prediction :  Pullover
# Actual :  Pullover
# Prediction :  Trouser
# Actual :  Trouser
# Prediction :  Trouser
# Actual :  Trouser
# Prediction :  Shirt
# Actual :  Shirt
# Prediction :  Trouser
# Actual :  Trouser
# Prediction :  Coat
# Actual :  Coat
# Prediction :  Shirt
# Actual :  Shirt
# Prediction :  Sandal
# Actual :  Sandal
# Prediction :  Sneaker
# Actual :  Sneaker
# Prediction :  Coat
# Actual :  Coat
# Prediction :  Sandal
# Actual :  Sandal
# Prediction :  Sneaker
# Actual :  Sneaker
# Prediction :  Dress
# Actual :  Dress
# Prediction :  Coat
# Actual :  Coat
# Prediction :  Trouser
# Actual :  Trouser
# Prediction :  Pullover
# Actual :  Pullover
# Prediction :  Coat
# Actual :  Coat
# Prediction :  Bag
# Actual :  Bag
# Prediction :  Tshirt
# Actual :  Tshirt
# Prediction :  Pullover
# Actual :  Pullover
# Prediction :  Sandal
# Actual :  Sandal
# Prediction :  Sneaker
# Actual :  Sneaker
# Prediction :  Sandal
# Actual :  Boot
# Prediction :  Trouser
# Actual :  Trouser
